# %%
import pandas as pd

# %%
miRNA_A=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/miRNA/mir1_decrease.csv")
miRNA_B=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/miRNA/mir155_decrease.csv")
both=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/miRNA/Both_target.csv")
reader=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/Reader/statistical_decrease_Reader.csv")

# %%
A_reader=pd.merge(miRNA_A,reader,on="Gene symbol")
A_reader
# Out:
#   RefseqAccession  logfold_TE Gene symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0       NM_006345   -0.746148     SLC30A9            81.62           33.99
# 1       NM_031954   -0.461210      KCTD10            16.81            7.69
# 2       NM_000629   -1.557137      IFNAR1            13.22            3.30
#
#    ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# 0                           -1.26           66.78          72.64
# 1                           -1.13           10.83          11.91
# 2                           -2.00           11.52           9.73
#
#    polyA_log2(siYTHDF1/siControl)1  TE_log2(siYTHDF1/siControl)1    ...     \
# 0                             0.12                         -1.39    ...
# 1                             0.14                         -1.27    ...
# 2                            -0.24                         -1.76    ...
#
#    siControl_RNA2  siYTHDF1_RNA2  polyA_log2(siYTHDF1/siControl)2  \
# ...

# %%
B_reader=pd.merge(miRNA_B,reader,on="Gene symbol")
B_reader
# Out:
#   RefseqAccession  logfold_TE Gene symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0    NM_001082480   -0.426549      ZNF623             7.29            1.40
# 1    NM_001145525   -0.427599       RAI14            47.10           27.93
# 2       NM_012197   -0.444538     RABGAP1            50.76           18.44
# 3       NM_000629   -0.886317      IFNAR1            13.22            3.30
# 4       NM_080599   -0.726391        UPF2            15.78            1.89
# 5       NM_004757   -0.448790       AIMP1           301.67          135.88
#
#    ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# 0                           -2.38            6.35           6.72
# 1                           -0.75           23.00          29.25
# 2                           -1.46           15.56          19.46
# 3                           -2.00           11.52           9.73
# 4                           -3.06            5.39           4.91
# ...

# %%
B_reader[["Gene symbol"]]
# Out:
#   Gene symbol
# 0      ZNF623
# 1       RAI14
# 2     RABGAP1
# 3      IFNAR1
# 4        UPF2
# 5       AIMP1

# %%
both_reader=pd.merge(both,reader,on="Gene symbol")
both_reader
# Out:
#   RefseqAccession  logfold_TE_mir1  logfold_TE_mir155 Gene symbol  \
# 0       NM_000629        -1.557137          -0.886317      IFNAR1
#
#    siControl_ribo1  siYTHDF1_ribo1  ribo_log2(siYTHDF1/siControl)1  \
# 0            13.22             3.3                            -2.0
#
#    siControl_RNA1  siYTHDF1_RNA1  polyA_log2(siYTHDF1/siControl)1    ...     \
# 0           11.52           9.73                            -0.24    ...
#
#    siControl_RNA2  siYTHDF1_RNA2  polyA_log2(siYTHDF1/siControl)2  \
# 0            9.22           9.61                             0.06
#
#    TE_log2(siYTHDF1/siControl)2  ribo_log2(siYTHDF1/siControl)ave  \
# 0                         -0.62                             -1.28
#
#    polyA_log2(siYTHDF1/siControl)ave  TE_log2(siYTHDF1/siControl)ave  \
# 0                              -0.09                           -1.19
#
#      pvalue  color     logpv
# 0  0.083775    red  1.076888
#
# [1 rows x 24 columns]

# %%
A_reader.to_csv("mir1_reader.csv",index=False)
B_reader.to_csv("mir155_reader.csv",index=False)
