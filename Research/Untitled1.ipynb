# %%
import pandas as pd

# %%
reader=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/Reader/statistical_decrease_Reader.csv")
writer=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/Writer/GSE63591_D-METTL3-Ribosome_profiling.csv")

# %%
reader.head(10)
# Out:
#   Gene symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0      ADRA1B             2.79            0.15
# 1       AGGF1            24.16           10.18
# 2      AHCYL1           113.36           22.35
# 3       AIMP1           301.67          135.88
# 4       AP4B1            19.52            7.26
# 5       APBB2             4.75            1.59
# 6      APCDD1             2.54            0.28
# 7    ARHGAP18            88.71           13.59
# 8    ARHGAP27             6.89            2.48
# 9      ARMC10             8.92            3.54
#
#    ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# 0                           -4.18            2.12           2.05
# 1                           -1.25           12.45          11.85
# 2                           -2.34           25.56          25.58
# 3                           -1.15           18.37          18.32
# 4                           -1.43            5.46           5.52
# ...

# %%
writer.head(10)
# Out:
#   Gene symbol  siControl-ribo  siMETTL3-ribo  ribo_log2(siMETTL3/siControl)  \
# 0      SAMD11           12.65           9.22                          -0.46
# 1      KLHL17            0.87           1.06                           0.29
# 2     PLEKHN1            0.67           1.54                           1.21
# 3       ISG15           83.81        5348.97                           6.00
# 4        AGRN            8.86           7.48                          -0.24
# 5     B3GALT6            0.88           1.43                           0.70
# 6       PUSL1           14.83           8.75                          -0.76
# 7      GLTPD1            5.63           4.20                          -0.42
# 8   LOC148413            4.98           2.93                          -0.76
# 9      ATAD3C            0.21           1.04                           2.29
#
#    siControl-RNA  siMETTL3-RNA  polyA_log2(siMETTL3/siControl)  \
# 0          57.87         21.90                           -1.40
# ...

# %%
reader_target_gene=[]
for gene in reader["Gene symbol"]:
    reader_target_gene.append(gene)
reader_target_gene
# Out:
# ['ADRA1B',
#  'AGGF1',
#  'AHCYL1',
#  'AIMP1',
#  'AP4B1',
#  'APBB2',
#  'APCDD1',
#  'ARHGAP18',
#  'ARHGAP27',
#  'ARMC10',
#  'ASXL2',
#  'BCR',
#  'BRD7',
#  'BZW2',
#  'C14orf1',
#  'C17orf85',
#  'C1orf174',
#  'C20orf112',
#  'C3orf17',
#  'CCAR1',
#  'CCDC71L',
#  'CCDC88A',
#  'CCT5',
#  'CDC123',
#  'CHERP',
#  'CLASP2',
#  'COX18',
#  'CRAMP1L',
#  'CROT',
#  'CTAGE5',
#  'CWC25',
#  'CYB5D1',
#  'DCK',
#  'DDR2',
#  'DLG1',
#  'DMXL1',
#  'DSCC1',
#  'DZIP1L',
#  'E2F7',
#  'EDEM2',
#  'ELK3',
#  'EPS8',
#  'ERG',
#  'EXOSC7',
#  'FAM109B',
#  'FAM129A',
#  'FAM175B',
#  'FAM21C',
#  'FAM49B',
#  'FAU',
#  'FDXACB1',
#  'FERMT1',
#  'FKBP5',
#  'FSD1',
#  'GAS2L3',
#  'GCC1',
#  'GDF11',
#  'GFM1',
#  'GFOD1',
#  'GIN1',
#  'GLT8D2',
#  'GTF2H5',
#  'GTSE1',
#  'HERC4',
#  'HOMER1',
#  'HSD17B1',
#  'HUS1',
#  'IDI1',
#  'IFNAR1',
#  'ING1',
#  'INPP4A',
#  'JMY',
#  'KBTBD6',
#  'KCTD10',
#  'KDM4D',
#  'KIAA1456',
#  'KLF9',
#  'KLHL21',
#  'LARP7',
#  'LIN9',
# ...

# %%
reader_target=[]
non_target=[]
for i in range(0,len(writer)):
    col=writer.iloc[i]
    gene=col["Gene symbol"]
    if gene not in reader_target_gene:
        non_target.append(col)
    elif gene in reader_target_gene:
        reader_target.append(col)
    else:
        print("Error")

reader_target=pd.DataFrame(reader_target)
non_target=pd.DataFrame(non_target)
non_target
# Out:
#       Gene symbol  siControl-ribo  siMETTL3-ribo  \
# 0          SAMD11           12.65           9.22
# 1          KLHL17            0.87           1.06
# 2         PLEKHN1            0.67           1.54
# 3           ISG15           83.81        5348.97
# 4            AGRN            8.86           7.48
# 5         B3GALT6            0.88           1.43
# 6           PUSL1           14.83           8.75
# 7          GLTPD1            5.63           4.20
# 8       LOC148413            4.98           2.93
# 9          ATAD3C            0.21           1.04
# 10         ATAD3B            4.47           2.80
# 11         ATAD3A            6.45           5.09
# 12           MIB2            0.81           1.18
# 13          PRKCZ            2.79           3.71
# 14            SKI            2.23           1.60
# 15           RER1           12.44          11.00
# 16        FAM213B            2.70           2.30
# 17       ARHGEF16            3.21           2.75
# ...

# %%
import numpy as  np
from matplotlib import pyplot as plt
import seaborn as sns

sns.set()
sns.set_style('whitegrid')
sns.set_palette('gray')

np.random.seed(2018)

x1 = np.random.normal(10, 2, 20)
x2 = np.random.normal(15, 3, 20)
x3 = np.random.normal(5, 1, 20)

fig = plt.figure()
ax = fig.add_subplot(1, 1,1)
ax.boxplot([non_target["TE_log2(siMETTL3/siControl)"], reader_target["TE_log2(siMETTL3/siControl)"]], labels=['Control', 'Reader_target'])
#ax.set_xlabel('tissue')
ax.set_ylabel('Translation Efficiency')
ax.set_ylim(-5, 5)

plt.show()
# Out:
# /Users/miyakesho/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
eraser=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/Eraser/Eraser_logfold.csv")
eraser.head(10)
# Out:
#       GeneID        Symbol                                        Description  \
# 0  100287102       DDX11L1  DEAD/H (Asp-Glu-Ala-Asp/His) box helicase 11 l...
# 1      79501         OR4F5  olfactory receptor, family 4, subfamily F, mem...
# 2  100132062  LOC100132062                       uncharacterized LOC100132062
# 3  100132062  LOC100132062                       uncharacterized LOC100132062
# 4      81399        OR4F16  olfactory receptor, family 4, subfamily F, mem...
# 5     643837     LOC643837                          uncharacterized LOC643837
# 6     148398        SAMD11           sterile alpha motif domain containing 11
# 7     339451        KLHL17                         kelch-like 17 (Drosophila)
# 8      84069       PLEKHN1  pleckstrin homology domain containing, family ...
# 9       9636         ISG15                      ISG15 ubiquitin-like modifier
#
#                                      RefseqAccession     logKD     logCL  \
# ...

# %%
r_merge=reader_target.set_index('Gene symbol')
e_merge=eraser.set_index('Symbol')

merge=pd.merge(r_merge,e_merge, left_index=True, right_index=True)

# %%
merge
# Out:
#            siControl-ribo  siMETTL3-ribo  ribo_log2(siMETTL3/siControl)  \
# ADRA1B               0.69           0.54                          -0.35
# AGGF1                8.04          11.10                           0.47
# AHCYL1             100.29          47.34                          -1.08
# AIMP1               43.91          37.76                          -0.22
# AP4B1               12.25          16.20                           0.40
# APBB2                2.89           4.21                           0.54
# APCDD1               0.33           0.37                           0.15
# ARHGAP18           103.11          85.19                          -0.28
# ARHGAP27             1.15           1.51                           0.40
# ARHGAP27             1.15           1.51                           0.40
# ARHGAP27             1.15           1.51                           0.40
# ARHGAP27             1.15           1.51                           0.40
# ...

# %%
import numpy as  np
from matplotlib import pyplot as plt
import seaborn as sns

sns.set()
sns.set_style('whitegrid')
sns.set_palette('gray')

np.random.seed(2018)


fig = plt.figure()
ax = fig.add_subplot(1, 1,1)
ax.boxplot([eraser["logfold"],merge["logfold"]], labels=['Control', 'Reader_target'])
#ax.set_xlabel('tissue')
ax.set_ylabel('Translation Efficiency')
ax.set_ylim(-1, 1)

plt.show()
# Out:
# /Users/miyakesho/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
