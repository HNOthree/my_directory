# %%
#それぞれのターゲットとしている領域にオーバーラップがあるのか調査

# %%
import pandas as pd

# %%
rep1_YTHDF1_target_list=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/PARCLIP_1.csv")
rep2_YTHDF1_target_list=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/PARCLIP_2.csv")
rep2_YTHDF1_target_list.head(10)
# Out:
#   Gene_symbol                                          Name  Peak_sum  \
# 0        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 1        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 2        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 3        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 4        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 5        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 6        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 7        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 8        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
# 9        MLL2  myeloid/lymphoid or mixed-lineage leukemia 2        93
#
#    Mutation_sum Chromosome       Start         End Strand  Peak_mutation  \
# 0           412      chr12  49432280.0  49432312.0      -            5.0
# ...

# %%
reference_genome=["HJKL+LKJHJKLKJHJKLKJHJK"]

# %%
search_seq=[""]
