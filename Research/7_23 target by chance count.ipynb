# %%
#偶然両方ターゲットになる遺伝子の数を計測

# %%
import pandas as pd

# %%
YTHDF1_data=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/downloads/GSE63591_C-Y1-Ribosome_profiling.csv")
YTHDF1_data.head(10)
# Out:
#   Gene_symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0      A4GALT            26.23           17.15
# 1        AAAS           160.80          148.75
# 2        AACS            43.31           18.43
# 3       AADAT             1.97            3.56
# 4       AAED1            57.07           33.83
# 5       AAGAB             6.59           13.31
# 6        AAK1             0.60            2.74
# 7        AAMP            36.81          127.20
# 8        AARS           706.51          315.19
# 9       AARS2             7.80           11.03
#
#    ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# 0                           -0.61            3.60           3.39
# 1                           -0.11           14.76          12.14
# 2                           -1.23            4.18           3.88
# 3                            0.86            2.99           2.18
# 4                           -0.75           14.53          17.41
# ...

# %%
miRNA1_data=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/symboled_miRNA1.csv")
miRNA155_data=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/symboled_miRNA155.csv")
miRNA1_data.head(10)
# Out:
#      Ref_seq  miRNA_rnaseq_log2fc  miRNA_footprint_log2fc  \
# 0  NM_017846            -0.295928               -0.378120
# 1  NM_001516            -0.053095                0.294499
# 2  NM_001517             0.113749                0.271561
# 3  NM_004034             0.280818               -0.087530
# 4  NM_016649             0.872146                1.786011
# 5  NM_004749             0.153393                0.442090
# 6  NM_016640             0.644354                0.718117
# 7  NM_016641            -0.071881                0.064189
# 8  NM_001862            -0.264713               -0.212363
# 9  NM_001863            -0.223459               -0.614738
#
#    miRNA_TranslEff_log2fc Gene_symbol
# 0               -0.082192    TRNAU1AP
# 1                0.347595      GTF2H3
# 2                0.157811      GTF2H4
# 3               -0.368349       ANXA7
# 4                0.913865        ESF1
# 5                0.288697       TBRG4
# 6                0.073763      MRPS30
# ...

# %%
merge_mir1=pd.merge(YTHDF1_data,miRNA1_data,on="Gene_symbol")
merge_mir155=pd.merge(YTHDF1_data,miRNA155_data,on="Gene_symbol")
merge_mir1.head(10)
# Out:
#   Gene_symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0        AAMP            36.81          127.20
# 1       AARS2             7.80           11.03
# 2    AASDHPPT            34.79           60.04
# 3        AATF            66.13           49.56
# 4       ABCA7             4.59            6.06
# 5       ABCB6            61.78           88.19
# 6       ABCB7            66.89          100.77
# 7       ABCC1            29.32           32.11
# 8       ABCC4            27.17           33.44
# 9       ABCC5             9.76           18.78
#
#    ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# 0                            1.79           13.09          11.63
# 1                            0.50            2.62           3.18
# 2                            0.79           29.88          40.08
# 3                           -0.42           12.95          14.69
# 4                            0.40            2.96           3.42
# ...

# %%
gene_length1=len(merge_mir1)
gene_length155=len(merge_mir155)
print(gene_length1,gene_length155)
# Out:
# 2909 3511

# %%
miR1target=266+512
YTHDFtarget=1102+512

# %%
miR1_prob=miR1target/gene_length1
YTHDF1_prob=YTHDFtarget/gene_length1
miR1_chance=miR1_prob*YTHDF1_prob
print(miR1_prob,YTHDF1_prob,miR1_chance)
# Out:
# 0.26744585768305257 0.554829838432451 0.14838694200771635

# %%
miR1_chance*gene_length1
# Out:
# 431.6576143004469

# %%
miR155_target=400+249
YTHDF1_target=400+1634

# %%
miR155_prob=miR155_target/gene_length155
YTHDF1_prob=YTHDF1_target/gene_length155
miR155_chance=miR155_prob*YTHDF1_prob
print(miR155_prob,YTHDF1_prob,miR155_chance)
# Out:
# 0.1848476217601823 0.5793221304471661 0.10708631804620074

# %%
miR155_chance*gene_length155
# Out:
# 375.98006266021076
