# %%
import pandas as pd

# %%
rmbase_list=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/miRNA/RMBase_miRNA_target.csv")
miRNA1_list=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/method5/mir1_reader.csv")
miRNA2_list=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/method5/mir155_reader.csv")

# %%
miRNA1_rmbase=pd.merge(miRNA1_list,rmbase_list,on="Gene symbol")
miRNA1_rmbase.to_csv("miRNA1_rmbase.csv",index=False)
miRNA1_rmbase
# Out:
#    RefseqAccession  logfold_TE Gene symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 1        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 2        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 3        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 4        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 5        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 6        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 7        NM_006345   -0.746148     SLC30A9            81.62           33.99
# 8        NM_031954   -0.461210      KCTD10            16.81            7.69
# 9        NM_000629   -1.557137      IFNAR1            13.22            3.30
# 10       NM_000629   -1.557137      IFNAR1            13.22            3.30
#
# ...

# %%
miRNA2_rmbase=pd.merge(miRNA2_list,rmbase_list,on="Gene symbol")
miRNA2_rmbase.to_csv("miRNA155_rmbase.csv",index=False)
miRNA2_rmbase
# Out:
#    RefseqAccession  logfold_TE Gene symbol  siControl_ribo1  siYTHDF1_ribo1  \
# 0     NM_001145525   -0.427599       RAI14            47.10           27.93
# 1     NM_001145525   -0.427599       RAI14            47.10           27.93
# 2        NM_012197   -0.444538     RABGAP1            50.76           18.44
# 3        NM_012197   -0.444538     RABGAP1            50.76           18.44
# 4        NM_000629   -0.886317      IFNAR1            13.22            3.30
# 5        NM_000629   -0.886317      IFNAR1            13.22            3.30
# 6        NM_080599   -0.726391        UPF2            15.78            1.89
# 7        NM_080599   -0.726391        UPF2            15.78            1.89
# 8        NM_080599   -0.726391        UPF2            15.78            1.89
# 9        NM_080599   -0.726391        UPF2            15.78            1.89
# 10       NM_004757   -0.448790       AIMP1           301.67          135.88
#
# ...

# %%
miRNA1_rmbase.groupby("Gene symbol").count()
# Out:
#              RefseqAccession  logfold_TE  siControl_ribo1  siYTHDF1_ribo1  \
# Gene symbol
# IFNAR1                     2           2                2               2
# KCTD10                     1           1                1               1
# SLC30A9                    8           8                8               8
#
#              ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# Gene symbol
# IFNAR1                                    2               2              2
# KCTD10                                    1               1              1
# SLC30A9                                   8               8              8
#
#              polyA_log2(siYTHDF1/siControl)1  TE_log2(siYTHDF1/siControl)1  \
# Gene symbol
# IFNAR1                                     2                             2
# KCTD10                                     1                             1
# SLC30A9                                    8                             8
#
# ...

# %%
miRNA2_rmbase.groupby("Gene symbol").count()
# Out:
#              RefseqAccession  logfold_TE  siControl_ribo1  siYTHDF1_ribo1  \
# Gene symbol
# AIMP1                      1           1                1               1
# IFNAR1                     2           2                2               2
# RABGAP1                    2           2                2               2
# RAI14                      2           2                2               2
# UPF2                       4           4                4               4
#
#              ribo_log2(siYTHDF1/siControl)1  siControl_RNA1  siYTHDF1_RNA1  \
# Gene symbol
# AIMP1                                     1               1              1
# IFNAR1                                    2               2              2
# RABGAP1                                   2               2              2
# RAI14                                     2               2              2
# UPF2                                      4               4              4
#
# ...
