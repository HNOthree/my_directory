# %%
#PARCLIPのデータからどこの領域に結合しやすいかみる

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
PARCLIP=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/PARCLIP_1.csv")
PARCLIP2=pd.read_csv("/Users/miyakesho/Google_Drive/master/research/csv/PARCLIP_2.csv")
print(len(PARCLIP),len(PARCLIP2))
# Out:
# 19618 47716

# %%
PARCLIP=PARCLIP.append(PARCLIP2)
PARCLIP.head(100)
# Out:
#    Gene_symbol                                               Name  Peak_sum  \
# 0         PLEC                                            plectin      45.0
# 1         PLEC                                            plectin      45.0
# 2         PLEC                                            plectin      45.0
# 3         PLEC                                            plectin      45.0
# 4         PLEC                                            plectin      45.0
# 5         PLEC                                            plectin      45.0
# 6         PLEC                                            plectin      45.0
# 7         PLEC                                            plectin      45.0
# 8         PLEC                                            plectin      45.0
# 9         PLEC                                            plectin      45.0
# 10        PLEC                                            plectin      45.0
# ...

# %%
sample_df=PARCLIP.groupby(["Peak_sum",'Region']).count()
sample_df
# Out:
#                  Gene_symbol  Name  Mutation_sum  Chromosome  Start   End  \
# Peak_sum Region
# 1.0      3UTR           1767  1767          1767        1767   1767  1767
#          5UTR            173   173           173         173    173   173
#          CDS            1988  1988          1988        1988   1988  1988
#          Intron          544   544           544         544    544   544
#          UTR             361   361           361         361    361   361
# 2.0      3UTR           2398  2398          2398        2398   2398  2398
#          5UTR            159   159           159         159    159   159
#          CDS            2362  2362          2362        2362   2362  2362
#          Intron          460   460           460         460    460   460
#          UTR             245   245           245         245    245   245
# 3.0      3UTR           2337  2337          2337        2337   2337  2337
# ...

# %%
PARCLIP.groupby('Region').count()
# Out:
#         Gene_symbol   Name  Peak_sum  Mutation_sum  Chromosome  Start    End  \
# Region
# 3UTR          29225  29225     29225         29225       29225  29225  29225
# 5UTR           1907   1907      1907          1907        1907   1907   1907
# CDS           30240  30240     30240         30240       30240  30240  30240
# Intron         4313   4313      4313          4313        4313   4313   4313
# UTR            1649   1649      1649          1649        1649   1649   1649
#
#         Strand  Peak_mutation
# Region
# 3UTR     29225          29225
# 5UTR      1907           1907
# CDS      30240          30240
# Intron    4313           4313
# UTR       1649           1649
