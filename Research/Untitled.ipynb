# %% [markdown]
# miRNAとEraserのデータを結合

# %%
import pandas as pd

# %%
miRNA=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/miRNA/miRNA_GSE21992_mir1.csv")
Eraser=pd.read_csv("/Users/miyakesho/Box Sync/Personal/m6A/data/phase2/Eraser/Eraser_logfold.csv")

# %%
merge=pd.merge(miRNA,Eraser,on="RefseqAccession")
merge
# Out:
#     RefseqAccession  logfold_TE  GeneID    Symbol  \
# 0         NM_017845   -0.380195   54951    COMMD8
# 1         NM_001514    0.013736    2959     GTF2B
# 2         NM_030571    0.317635   80762    NDFIP1
# 3         NM_004423   -0.180786    1857      DVL3
# 4         NM_002737   -0.146900    5578     PRKCA
# 5         NM_006062   -0.007127   10322     SMYD5
# 6         NM_006454   -0.312105   10608      MXD4
# 7         NM_024652   -0.042080   79705     LRRK1
# 8         NM_024656   -0.286626   79709   GLT25D1
# 9         NM_001414   -0.303841    1967    EIF2B1
# 10        NM_014762   -0.282514    1718    DHCR24
# 11        NM_005255    0.271714    2580       GAK
# 12        NM_032270   -0.916742   84230    LRRC8C
# 13        NM_006868   -0.026644   11031     RAB31
# 14        NM_032177    0.028565   51808      PHAX
# 15        NM_002356    0.033033    4082    MARCKS
# 16        NM_003632   -1.278860    8506   CNTNAP1
# 17        NM_000430   -0.377835    5048  PAFAH1B1
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(merge.logfold,bins=50)
plt.show()
